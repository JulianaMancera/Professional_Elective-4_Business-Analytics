# %% [markdown]
# **Lab Quiz 1 - Markdown and Python Basics**

# %% [markdown]
# Create a python program that collects student information from the user via console input.
#
# 1. Prompts for last name, first name, section, program, and birth year.  It then computes the student's age (2025 - birth year).
#
# 2. Prompt also hobby1, hobby2, hobby3 and store it on a list named hobbies.
#
# 3. The collected last name, first name, section, program, hobbies, and computed age are stored in a dictionary named student_info.
#
# 4. Print the content of the dictionary by concatenated last name and first name, program, section, hobbies, and age.

# %%
# STUDENT INFO
print("---------------------------")
print("🏫 Student Information 📚")
print("---------------------------")
last_name = input("Enter your last name: ")
first_name = input("Enter your first name: ")
section = input("Enter your section: ")
program = input("Enter your program: ")
birth_year = int(input("Enter your birth year: "))
age = 2025 - birth_year

print("-----------------------")
print("🏉 Hobbies Section 🏸")
print("-----------------------")
hobby1 = input("Enter your first hobby: ")
hobby2 = input("Enter your second hobby: ")
hobby3 = input("Enter your third hobby: ")
hobbies = [hobby1, hobby2, hobby3]

student = {
    "last_name": last_name,
    "first_name": first_name,
    "section": section,
    "program": program,
    "hobbies": hobbies,
    "age": age
}
print("\n=================================")
print("✨ Full details of the Student✨ ")
print("===================================")
print(f"Student Name: {student['first_name']} {student['last_name']}")
print(f"Program: {student['program']}")
print(f"Section: {student['section']}")
print(f"Hobbies: {student['hobbies']}")
print(f"Age: {student['age']}")
# Out:
# ---------------------------
# 🏫 Student Information 📚
# ---------------------------
# -----------------------
# 🏉 Hobbies Section 🏸
# -----------------------
#
# =================================
# ✨ Full details of the Student✨
# ===================================
# Student Name: Juliana Mancera
# Program: Bachelor of Science in Computer Science
# Section: 3BSCS-2
# Hobbies: ['Listening to music', 'Playing video games', 'Sleep']
# Age: 22

# %% [markdown]
# **Google Colab Full Details**

# %% [markdown]
# ![image.png](attachment:image.png)
